# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
current_path = '/content/drive/My Drive/Colab Notebooks/Project_GANder/gankook_cuda/semantic-segmentation-pytorch/'

import os

os.chdir(current_path)
# !ls
# Out:
#  ade20k-resnet50dilated-ppm_deepsup
#  batch_tensor
#  Building_images
#  ckpt
# 'Color Synthetic All_Color.ipynb'
# 'Color Synthetic All_Color_Shift.ipynb'
# 'Color Synthetic.ipynb'
# 'Color Synthetic Randomic.ipynb'
#  config
#  cooperative_scene_parsing
#  data
#  decoder_tensor_image.png
#  demo_test.sh
#  download_ADE20K.sh
#  DrivingLaneDetection
#  DuLa-Net
#  edge_tensor
#  edge_tensor_image.png
#  encoder_tensor_image.png
#  eval_multipro.py
#  eval.py
#  extractRect.py
# 'Layout Estimation.ipynb'
#  LICENSE
#  lsun
#  lsun-room
#  lsun-room-dsc
#  mask_data
#  mit_semseg
#  pretrained
#  problem_test_data
#  problem_test_result
#  __pycache__
#  pytorch_refinenet
#  pytorch.room.layout
#  Pytorch-UNet
#  README.md
#  refer_data
#  requirements.txt
#  roomnet
#  ScanNet-Layout
# 'Scene Estimation.ipynb의 사본'
#  setup.py
#  SSP.ipynb
#  SSP_plus_weights_Ceiling.ipynb
#  SSP_plus_weights_Floor.ipynb
#  SSP_plus_weights_Tester.ipynb
#  SSP_plus_weights_Video_Tester.ipynb
#  SSP_plus_weights_Wall.ipynb
#  syn_result
#  teaser
#  tensor_image.png
#  test_data
#  test.py
#  test_result
#  train.py
#  Vanishing-Point-Detection-and-3D-Plane-Segmentation
#  video_data
#  video_result
#  video_syn_result

# %% [markdown]
# ### Refer Data Rotation & Rescaling

# %%
object_ = 'ceiling'
refer_path = './refer_data/' + object_ + '/'

scale_factor = 5
rotate_factor = 15

import os
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random
import os

try:
  os.makedirs(refer_path + 'scaled/')

except Exception as e:
  print(e)

for index, refer_image in enumerate(os.listdir(refer_path)):
  
  if os.path.isdir(refer_path + refer_image):
    continue
  if not refer_image.endswith('.jpg'):
    continue

  refer = Image.open(refer_path + refer_image)
  # refer = cv2.imread(refer_path + refer_image)
  # plt.imshow(refer)
  # plt.show()

  # refer = refer.resize((int(refer.size[0] / 2), int(refer.size[1] / 2)))
  # refer = refer.resize((refer.size[0] * 2, refer.size[1] * 2))
  refer = np.asarray(refer)
  # print(refer.shape)
  refer = np.tile(refer, (scale_factor, scale_factor, 1))
  # print(scaled_refer.shape)

  refer = Image.fromarray(refer)
  refer_org = np.asarray(refer.copy())

  refer = refer.rotate(rotate_factor)
  refer = np.asarray(refer)

  #   회전 이전의 그림의 중심으로한 원에 내접하는 정사각형을 추출한다 -> final refer data     #
  center_p = (int(refer.shape[0] / 2), int(refer.shape[1] / 2))
  # print(center_p)
  radius = min(center_p)
  # print(radius)
  half_square_edge = radius / (2 ** 0.5)
  # square_point = 
  min_x, max_x = center_p[0] - half_square_edge, center_p[0] + half_square_edge
  min_y, max_y = center_p[1] - half_square_edge, center_p[1] + half_square_edge

  # cv2.circle(refer, center_p[::-1], int(radius), (255, 0, 0), 10)
  # cv2.circle(refer, center_p[::-1], 50, (255, 0, 0), -1)
  # cv2.circle(refer_org, center_p[::-1], int(radius), (255, 0, 0), 10)
  # cv2.circle(refer_org, center_p[::-1], 50, (255, 0, 0), -1)
  # plt.imshow(np.hstack((refer_org, refer)))
  # plt.show()

  refer = refer[int(min_x):int(max_x), int(min_y):int(max_y)]

  # refer = refer.resize((np.asarray(refer).shape[0] * 2, np.asarray(refer).shape[1] * 2))
  plt.imshow(refer)
  plt.show()

  Image.fromarray(refer).save(refer_path + 'scaled/' + refer_image)

  # break
# Out:
# [Errno 17] File exists: './refer_data/ceiling/scaled/'

# %% [markdown]
# ### Randomic Synthetic Image

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random
import os

def min_max_scale(x):

  scaled_x = (x - x.min()) / (x.max() - x.min())
  return scaled_x

object_ = 'wall'

#     Image Version     #
# mask_path = './test_result/' + object_ + '/'
mask_path = './mask_data/' + object_ + '/'
# refer_path = './refer_data/' + object_ + '/'
refer_path = './refer_data/' + object_ + '/' + 'scaled/'
save_path = mask_path.replace('mask_data', 'syn_result')

#     Video Version     #
# mask_path = './video_result/6/' + object_ + '/'
# refer_path = './refer_data/' + object_ + '/'
# # refer_path = './refer_data/' + object_ + '/' + 'scaled/'
# save_path = mask_path.replace('video_result', 'video_syn_result')

refer_shift = False

try:
  os.makedirs(save_path)

except Exception as e:
  print(e)


mask_list = list()
color_number_list = np.arange(190, 256)

refer_list = list()
for index in range(4):
  rand_color_list = list()
  for i in range(3):
    rand_color_list.append(random.choice(color_number_list))
  rand_color = np.array(rand_color_list).reshape(1, -1)
  refer_list.append(rand_color)
  
for mask in (os.listdir(mask_path)):

  if os.path.isdir(mask_path + mask):
      continue
  # mask = '10-Amazing-Wall-Texture-Designs-To-Revive-Your-Living-Room-1024x640.png'
  print('mask :', mask)

  new_save_path = save_path + mask.replace('.png', '') + '/'
  if not refer_shift:
    try:
      os.makedirs(new_save_path)
    
    except Exception as e:
      print(e)

  # rand_refer_list = random.sample(os.listdir(refer_path), 5)
  # for index, refer_image in enumerate(rand_refer_list):
  # # for index, refer_image in enumerate(os.listdir(refer_path)):
  #   # refer_image = 'grata.jpg'
  #   if os.path.isdir(refer_path + refer_image):
  #     continue
  #   print('refer_image :', refer_image)
  for index in range(5):
  
    image = Image.open(mask_path + mask)
    # image = cv2.imread(mask_path + mask)
    org, mask_img = np.split(np.array(image), 2, axis=1)
    # print(org.shape, mask_img.shape)


    #       Refer Shifting    #
    scene_point = [79, 142, 208, 267]
    if refer_shift:
      frame_num = int(mask.split('.')[0])
      if frame_num < scene_point[0]:
        final_img = Image.fromarray(org)
        final_img.save(save_path + '%s_' % index + mask.replace('png', 'jpg'))
        continue
      elif frame_num < scene_point[1]:
        rand_color = refer_list[0]
      elif frame_num < scene_point[2]:
        rand_color = refer_list[1]
      elif frame_num < scene_point[3]:
        rand_color = refer_list[2]
      else:
        rand_color = refer_list[3]
    # mask_img = min_max_scale(mask_img)
    # plt.imshow(mask_img)
    # plt.show()

    img_size = (mask_img.shape[1], mask_img.shape[0])   

    # rand_color_list = list()
    # for i in range(3):
    #   rand_color_list.append(random.choice(color_number_list))
    # rand_color = np.array(rand_color_list).reshape(1, -1)
    # print(rand_color)
    refer = np.tile(rand_color, (mask_img.shape[0], mask_img.shape[1], 1))

    # refer = Image.open(refer_path + refer_image)
    # refer = refer.resize(img_size)

    #     refer_image Warping     #
    #          Find Max Height Contour Point       #
    # if object_ is not 'wall':

    #   mask_img_gr = mask_img[:mask_img.shape[0] - 10, :mask_img.shape[1] - 10]
    #   gray = cv2.cvtColor(mask_img_gr, cv2.COLOR_RGB2GRAY)
    #   # gray = cv2.cvtColor(mask_img.astype(np.float32), cv2.COLOR_RGB2GRAY) * 255
    #   ret, thr = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    #   contours, _ = cv2.findContours(thr, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    #   # print(contours.shape)

    #   if object_ == 'floor':
    #     max_height_point = np.array([[mask_img.shape[0], mask_img.shape[1]]])
    #     # print(max_height_point)
    #     for contour in contours:
    #       # print(contour.shape)
    #       for point in contour:
    #         # print(point[0][1], max_height_point[0][1])
    #         if 0 < point[0][1] <= max_height_point[0][1]:
    #           # print(max_height_point[0][1])
    #           max_height_point = point
    #         # print(point)
    #         # break
    #       # ctr = contour.astype(np.int32)
    #       # cv2.drawContours(mask_img, [ctr], -1, (255, 0, 0), 5)
        
    #     #       Warping       #
    #     pts1 = np.float32([max_height_point[0], [0, gray.shape[1]], [gray.shape[0], gray.shape[1]]])
    #     pts2 = np.float32([[max_height_point[0][0], 0], [0, gray.shape[1]], [gray.shape[0], gray.shape[1]]])

    #   elif object_ == 'ceiling':
    #     max_height_point = np.array([[0, 0]])
    #     # print(max_height_point)
    #     for contour in contours:
    #       # print(contour.shape)
    #       for point in contour:
    #         # print(point[0][1], max_height_point[0][1])
    #         if point[0][1] >= max_height_point[0][1]:
    #           # print(max_height_point[0][1])
    #           max_height_point = point
    #         # print(point)
    #         # break
    #       # ctr = contour.astype(np.int32)
    #       # cv2.drawContours(mask_img, [ctr], -1, (255, 0, 0), 5)
        
    #     #       Warping       #
    #     pts1 = np.float32([[max_height_point[0][0], max_height_point[0][1]], [0, 0], [gray.shape[1], 0]])
    #     pts2 = np.float32([[max_height_point[0][0], gray.shape[0]], [0, 0], [gray.shape[1], 0]])

    #   matrix = cv2.getAffineTransform(pts2, pts1)

    #   refer = np.asarray(refer)
    #   refer = cv2.warpAffine(refer, matrix, (refer.shape[1], refer.shape[0]))

    # plt.imshow(refer)
    # plt.show()
    # break
    binary_mask = cv2.cvtColor(mask_img, cv2.COLOR_RGB2GRAY)

    mask_img = mask_img / 255.

    #     1.wall_mask * reference color image + (1 - wall_mask) * original_image)    #
    syn_ = mask_img * (refer) + (1 - mask_img) * org
    syn = mask_img * syn_ + (1 - mask_img) * org

    # syn = mask_img * (0.5 * np.array(refer) + 0.5 * org) + (1 - mask_img) * org
    # print(syn.max(), syn.min())
    # print(syn.shape)
    
    #       Brightness Reservation      #
    #     2.1st result's hsv('value') channel = w * wall_mask * reference hsv('value') + (1 - w) * (1 - wall_mask) * 1st hsv('value')
    org_hsv = cv2.cvtColor(np.uint8(org), cv2.COLOR_RGB2HSV)
    refer_hsv = cv2.cvtColor(np.uint8(refer), cv2.COLOR_RGB2HSV)
    syn_hsv = cv2.cvtColor(np.uint8(syn), cv2.COLOR_RGB2HSV)

    org_h, org_s, org_v = cv2.split(org_hsv)
    refer_h, refer_s, refer_v = cv2.split(refer_hsv)
    syn_h, syn_s, syn_v = cv2.split(syn_hsv)

    # mask_img = cv2.cvtColor(np.uint8(mask_img), cv2.COLOR_RGB2GRAY)
    # print(mask_img.shape)
    # print(refer_v.shape)
    # print(syn_v.shape)
    # final_syn_hsv = cv2.merge([syn_h, syn_s, syn_v])
    # plt.imshow(np.hstack((syn_h, syn_s, syn_v)))
    # plt.show()
    # plt.imshow(np.hstack((org_h, org_s, org_v)))
    # plt.show()

    hsv_added = cv2.addWeighted(org, 0.7, org_hsv, 0.3, 0)
    kernel_size, low_threshold, high_threshold = 5, 0, 150
    hsv_added = cv2.GaussianBlur(hsv_added, (kernel_size, kernel_size), 0)
    hsv_added = cv2.Canny(hsv_added, low_threshold, high_threshold)
    # hsv_added = np.invert(hsv_added)
    # plt.imshow(hsv_added)
    # plt.show()
    binary_edge = cv2.GaussianBlur(binary_mask, (kernel_size, kernel_size), 0)
    binary_edge = cv2.Canny(binary_edge, low_threshold, high_threshold)
    # plt.imshow(binary_edge)
    # plt.show()

    w = .5
    # print(syn_v.min(), syn_v.max())
    # syn_v = w * mask_img * refer_v + (1 - w) * (1 - mask_img) * org_v
    prev_syn_v = syn_v.copy()
    syn_v_im = w * syn_v + (1 - w) * org_v
    syn_v = w * syn_v_im + (1 - w) * org_v
    # syn_v = mask_img * syn_v * k + (1 - mask_img) * org_v
    syn_v = syn_v.astype(np.uint8)
    # print(syn_v.min(), syn_v.max())

    # prev_syn_h = syn_h.copy()
    # syn_h = w * syn_h + (1 - w) * org_h
    # syn_h = syn_h.astype(np.uint8)

    # syn_s = w * syn_s + (1 - w) * org_s
    # syn_s = syn_s.astype(np.uint8)


    # prev_syn_s = syn_s.copy()
    # syn_s = w * syn_s + (1 - w) * org_s
    # syn_s = syn_s.astype(np.uint8)

    # print(syn_h.dtype)
    # print(syn_s.dtype)
    # print(syn_v.dtype)
    im_syn_hsv = cv2.merge([syn_h, syn_s, syn_v_im.astype(np.uint8)])
    im_syn = cv2.cvtColor(im_syn_hsv, cv2.COLOR_HSV2RGB)

    final_syn_hsv = cv2.merge([syn_h, syn_s, syn_v])
    final_syn = cv2.cvtColor(final_syn_hsv, cv2.COLOR_HSV2RGB)

    # plt.imshow(np.hstack((org, syn_hsv, np.uint8(syn))))
    # # plt.imshow(mask_img)
    # # plt.imshow(cv2.add(org, np.invert(mask_img)))
    # plt.imshow(syn_hsv)
    # plt.show()

    # plt.imshow(org_v)
    # plt.imshow(np.hstack((prev_syn_v, syn_v)))
    # plt.imshow(np.hstack((syn_hsv, final_syn_hsv)))
    # plt.imshow(mask_img * 255)
    # plt.figure(figsize=(15, 10))
    # plt.imshow(np.hstack((org, np.uint8(syn_), np.uint8(syn), im_syn, final_syn)))
    plt.imshow(final_syn)
    # plt.imshow(np.hstack((org, final_syn)))

    # print(syn.shape)
    # print(syn_h.shape)
    # plt.imshow(np.hstack((syn_h, syn_s, syn_v)))
    # plt.imshow(cv2.merge((syn_h, syn_s, syn_v)))


    # plt.imshow(refer)
    # plt.imshow(1 - mask_img)
    plt.axis('off')
    plt.show()
    # plt.savefig(save_path + '%s_' % index + mask.replace('png', 'jpg'))

    # if not refer_shift:
    #   if index == 0:
    #     org_img = Image.fromarray(org)
    #     org_img.save(new_save_path + mask.replace('png', 'jpg'))
    #   final_img = Image.fromarray(final_syn)
    #   final_img.save(new_save_path + '%s_color_' % index + mask.replace('png', 'jpg'))

    # else:
    #   final_img = Image.fromarray(final_syn)
    #   final_img.save(save_path + '%s_' % index + mask.replace('png', 'jpg'))

    # break
  # break
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Image to Video

# %%
import cv2
import numpy as np
import glob
import os


video_path = 'video_syn_result/6/' + object_ + '/'
 
image_list = glob.glob(video_path + '*.jpg')
img_array = []
for i in range(len(image_list)):
  try:
    filename = video_path + '0_%s.0.jpg' % (i + 1)
    print('filename:', filename)
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)

  except:
    pass
 
 
out = cv2.VideoWriter(video_path.replace(object_ + '/', '') + 'syned_video.mp4', cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
# Out:
# filename: video_syn_result/6/wall/0_1.0.jpg
# filename: video_syn_result/6/wall/0_2.0.jpg
# filename: video_syn_result/6/wall/0_3.0.jpg
# filename: video_syn_result/6/wall/0_4.0.jpg
# filename: video_syn_result/6/wall/0_5.0.jpg
# filename: video_syn_result/6/wall/0_6.0.jpg
# filename: video_syn_result/6/wall/0_7.0.jpg
# filename: video_syn_result/6/wall/0_8.0.jpg
# filename: video_syn_result/6/wall/0_9.0.jpg
# filename: video_syn_result/6/wall/0_10.0.jpg
# filename: video_syn_result/6/wall/0_11.0.jpg
# filename: video_syn_result/6/wall/0_12.0.jpg
# filename: video_syn_result/6/wall/0_13.0.jpg
# filename: video_syn_result/6/wall/0_14.0.jpg
# filename: video_syn_result/6/wall/0_15.0.jpg
# filename: video_syn_result/6/wall/0_16.0.jpg
# filename: video_syn_result/6/wall/0_17.0.jpg
# filename: video_syn_result/6/wall/0_18.0.jpg
# filename: video_syn_result/6/wall/0_19.0.jpg
# filename: video_syn_result/6/wall/0_20.0.jpg
# filename: video_syn_result/6/wall/0_21.0.jpg
# filename: video_syn_result/6/wall/0_22.0.jpg
# filename: video_syn_result/6/wall/0_23.0.jpg
# filename: video_syn_result/6/wall/0_24.0.jpg
# filename: video_syn_result/6/wall/0_25.0.jpg
# filename: video_syn_result/6/wall/0_26.0.jpg
# filename: video_syn_result/6/wall/0_27.0.jpg
# filename: video_syn_result/6/wall/0_28.0.jpg
# filename: video_syn_result/6/wall/0_29.0.jpg
# filename: video_syn_result/6/wall/0_30.0.jpg
# filename: video_syn_result/6/wall/0_31.0.jpg
# filename: video_syn_result/6/wall/0_32.0.jpg
# filename: video_syn_result/6/wall/0_33.0.jpg
# filename: video_syn_result/6/wall/0_34.0.jpg
# filename: video_syn_result/6/wall/0_35.0.jpg
# filename: video_syn_result/6/wall/0_36.0.jpg
# filename: video_syn_result/6/wall/0_37.0.jpg
# filename: video_syn_result/6/wall/0_38.0.jpg
# filename: video_syn_result/6/wall/0_39.0.jpg
# filename: video_syn_result/6/wall/0_40.0.jpg
# filename: video_syn_result/6/wall/0_41.0.jpg
# filename: video_syn_result/6/wall/0_42.0.jpg
# filename: video_syn_result/6/wall/0_43.0.jpg
# filename: video_syn_result/6/wall/0_44.0.jpg
# filename: video_syn_result/6/wall/0_45.0.jpg
# filename: video_syn_result/6/wall/0_46.0.jpg
# filename: video_syn_result/6/wall/0_47.0.jpg
# filename: video_syn_result/6/wall/0_48.0.jpg
# filename: video_syn_result/6/wall/0_49.0.jpg
# filename: video_syn_result/6/wall/0_50.0.jpg
# filename: video_syn_result/6/wall/0_51.0.jpg
# filename: video_syn_result/6/wall/0_52.0.jpg
# filename: video_syn_result/6/wall/0_53.0.jpg
# filename: video_syn_result/6/wall/0_54.0.jpg
# filename: video_syn_result/6/wall/0_55.0.jpg
# filename: video_syn_result/6/wall/0_56.0.jpg
# filename: video_syn_result/6/wall/0_57.0.jpg
# filename: video_syn_result/6/wall/0_58.0.jpg
# filename: video_syn_result/6/wall/0_59.0.jpg
# filename: video_syn_result/6/wall/0_60.0.jpg
# filename: video_syn_result/6/wall/0_61.0.jpg
# filename: video_syn_result/6/wall/0_62.0.jpg
# filename: video_syn_result/6/wall/0_63.0.jpg
# filename: video_syn_result/6/wall/0_64.0.jpg
# filename: video_syn_result/6/wall/0_65.0.jpg
# filename: video_syn_result/6/wall/0_66.0.jpg
# filename: video_syn_result/6/wall/0_67.0.jpg
# filename: video_syn_result/6/wall/0_68.0.jpg
# filename: video_syn_result/6/wall/0_69.0.jpg
# filename: video_syn_result/6/wall/0_70.0.jpg
# filename: video_syn_result/6/wall/0_71.0.jpg
# filename: video_syn_result/6/wall/0_72.0.jpg
# filename: video_syn_result/6/wall/0_73.0.jpg
# filename: video_syn_result/6/wall/0_74.0.jpg
# filename: video_syn_result/6/wall/0_75.0.jpg
# filename: video_syn_result/6/wall/0_76.0.jpg
# filename: video_syn_result/6/wall/0_77.0.jpg
# filename: video_syn_result/6/wall/0_78.0.jpg
# filename: video_syn_result/6/wall/0_79.0.jpg
# filename: video_syn_result/6/wall/0_80.0.jpg
# filename: video_syn_result/6/wall/0_81.0.jpg
# filename: video_syn_result/6/wall/0_82.0.jpg
# filename: video_syn_result/6/wall/0_83.0.jpg
# filename: video_syn_result/6/wall/0_84.0.jpg
# filename: video_syn_result/6/wall/0_85.0.jpg
# filename: video_syn_result/6/wall/0_86.0.jpg
# filename: video_syn_result/6/wall/0_87.0.jpg
# filename: video_syn_result/6/wall/0_88.0.jpg
# filename: video_syn_result/6/wall/0_89.0.jpg
# filename: video_syn_result/6/wall/0_90.0.jpg
# filename: video_syn_result/6/wall/0_91.0.jpg
# filename: video_syn_result/6/wall/0_92.0.jpg
# filename: video_syn_result/6/wall/0_93.0.jpg
# filename: video_syn_result/6/wall/0_94.0.jpg
# filename: video_syn_result/6/wall/0_95.0.jpg
# filename: video_syn_result/6/wall/0_96.0.jpg
# filename: video_syn_result/6/wall/0_97.0.jpg
# filename: video_syn_result/6/wall/0_98.0.jpg
# filename: video_syn_result/6/wall/0_99.0.jpg
# filename: video_syn_result/6/wall/0_100.0.jpg
# filename: video_syn_result/6/wall/0_101.0.jpg
# filename: video_syn_result/6/wall/0_102.0.jpg
# filename: video_syn_result/6/wall/0_103.0.jpg
# filename: video_syn_result/6/wall/0_104.0.jpg
# filename: video_syn_result/6/wall/0_105.0.jpg
# filename: video_syn_result/6/wall/0_106.0.jpg
# filename: video_syn_result/6/wall/0_107.0.jpg
# filename: video_syn_result/6/wall/0_108.0.jpg
# filename: video_syn_result/6/wall/0_109.0.jpg
# filename: video_syn_result/6/wall/0_110.0.jpg
# filename: video_syn_result/6/wall/0_111.0.jpg
# filename: video_syn_result/6/wall/0_112.0.jpg
# filename: video_syn_result/6/wall/0_113.0.jpg
# filename: video_syn_result/6/wall/0_114.0.jpg
# filename: video_syn_result/6/wall/0_115.0.jpg
# filename: video_syn_result/6/wall/0_116.0.jpg
# filename: video_syn_result/6/wall/0_117.0.jpg
# filename: video_syn_result/6/wall/0_118.0.jpg
# filename: video_syn_result/6/wall/0_119.0.jpg
# filename: video_syn_result/6/wall/0_120.0.jpg
# filename: video_syn_result/6/wall/0_121.0.jpg
# filename: video_syn_result/6/wall/0_122.0.jpg
# filename: video_syn_result/6/wall/0_123.0.jpg
# filename: video_syn_result/6/wall/0_124.0.jpg
# filename: video_syn_result/6/wall/0_125.0.jpg
# filename: video_syn_result/6/wall/0_126.0.jpg
# filename: video_syn_result/6/wall/0_127.0.jpg
# filename: video_syn_result/6/wall/0_128.0.jpg
# filename: video_syn_result/6/wall/0_129.0.jpg
# filename: video_syn_result/6/wall/0_130.0.jpg
# filename: video_syn_result/6/wall/0_131.0.jpg
# filename: video_syn_result/6/wall/0_132.0.jpg
# filename: video_syn_result/6/wall/0_133.0.jpg
# filename: video_syn_result/6/wall/0_134.0.jpg
# filename: video_syn_result/6/wall/0_135.0.jpg
# filename: video_syn_result/6/wall/0_136.0.jpg
# filename: video_syn_result/6/wall/0_137.0.jpg
# filename: video_syn_result/6/wall/0_138.0.jpg
# filename: video_syn_result/6/wall/0_139.0.jpg
# filename: video_syn_result/6/wall/0_140.0.jpg
# filename: video_syn_result/6/wall/0_141.0.jpg
# filename: video_syn_result/6/wall/0_142.0.jpg
# filename: video_syn_result/6/wall/0_143.0.jpg
# filename: video_syn_result/6/wall/0_144.0.jpg
# filename: video_syn_result/6/wall/0_145.0.jpg
# filename: video_syn_result/6/wall/0_146.0.jpg
# filename: video_syn_result/6/wall/0_147.0.jpg
# filename: video_syn_result/6/wall/0_148.0.jpg
# filename: video_syn_result/6/wall/0_149.0.jpg
# filename: video_syn_result/6/wall/0_150.0.jpg
# filename: video_syn_result/6/wall/0_151.0.jpg
# filename: video_syn_result/6/wall/0_152.0.jpg
# filename: video_syn_result/6/wall/0_153.0.jpg
# filename: video_syn_result/6/wall/0_154.0.jpg
# filename: video_syn_result/6/wall/0_155.0.jpg
# filename: video_syn_result/6/wall/0_156.0.jpg
# filename: video_syn_result/6/wall/0_157.0.jpg
# filename: video_syn_result/6/wall/0_158.0.jpg
# filename: video_syn_result/6/wall/0_159.0.jpg
# filename: video_syn_result/6/wall/0_160.0.jpg
# filename: video_syn_result/6/wall/0_161.0.jpg
# filename: video_syn_result/6/wall/0_162.0.jpg
# filename: video_syn_result/6/wall/0_163.0.jpg
# filename: video_syn_result/6/wall/0_164.0.jpg
# filename: video_syn_result/6/wall/0_165.0.jpg
# filename: video_syn_result/6/wall/0_166.0.jpg
# filename: video_syn_result/6/wall/0_167.0.jpg
# filename: video_syn_result/6/wall/0_168.0.jpg
# filename: video_syn_result/6/wall/0_169.0.jpg
# filename: video_syn_result/6/wall/0_170.0.jpg
# filename: video_syn_result/6/wall/0_171.0.jpg
# filename: video_syn_result/6/wall/0_172.0.jpg
# filename: video_syn_result/6/wall/0_173.0.jpg
# filename: video_syn_result/6/wall/0_174.0.jpg
# filename: video_syn_result/6/wall/0_175.0.jpg
# filename: video_syn_result/6/wall/0_176.0.jpg
# filename: video_syn_result/6/wall/0_177.0.jpg
# filename: video_syn_result/6/wall/0_178.0.jpg
# filename: video_syn_result/6/wall/0_179.0.jpg
# filename: video_syn_result/6/wall/0_180.0.jpg
# filename: video_syn_result/6/wall/0_181.0.jpg
# filename: video_syn_result/6/wall/0_182.0.jpg
# filename: video_syn_result/6/wall/0_183.0.jpg
# filename: video_syn_result/6/wall/0_184.0.jpg
# filename: video_syn_result/6/wall/0_185.0.jpg
# filename: video_syn_result/6/wall/0_186.0.jpg
# filename: video_syn_result/6/wall/0_187.0.jpg
# filename: video_syn_result/6/wall/0_188.0.jpg
# filename: video_syn_result/6/wall/0_189.0.jpg
# filename: video_syn_result/6/wall/0_190.0.jpg
# filename: video_syn_result/6/wall/0_191.0.jpg
# filename: video_syn_result/6/wall/0_192.0.jpg
# filename: video_syn_result/6/wall/0_193.0.jpg
# filename: video_syn_result/6/wall/0_194.0.jpg
# filename: video_syn_result/6/wall/0_195.0.jpg
# filename: video_syn_result/6/wall/0_196.0.jpg
# filename: video_syn_result/6/wall/0_197.0.jpg
# filename: video_syn_result/6/wall/0_198.0.jpg
# filename: video_syn_result/6/wall/0_199.0.jpg
# filename: video_syn_result/6/wall/0_200.0.jpg
# filename: video_syn_result/6/wall/0_201.0.jpg
# filename: video_syn_result/6/wall/0_202.0.jpg
# filename: video_syn_result/6/wall/0_203.0.jpg
# filename: video_syn_result/6/wall/0_204.0.jpg
# filename: video_syn_result/6/wall/0_205.0.jpg
# filename: video_syn_result/6/wall/0_206.0.jpg
# filename: video_syn_result/6/wall/0_207.0.jpg
# filename: video_syn_result/6/wall/0_208.0.jpg
# filename: video_syn_result/6/wall/0_209.0.jpg
# filename: video_syn_result/6/wall/0_210.0.jpg
# filename: video_syn_result/6/wall/0_211.0.jpg
# filename: video_syn_result/6/wall/0_212.0.jpg
# filename: video_syn_result/6/wall/0_213.0.jpg
# filename: video_syn_result/6/wall/0_214.0.jpg
# filename: video_syn_result/6/wall/0_215.0.jpg
# filename: video_syn_result/6/wall/0_216.0.jpg
# filename: video_syn_result/6/wall/0_217.0.jpg
# filename: video_syn_result/6/wall/0_218.0.jpg
# filename: video_syn_result/6/wall/0_219.0.jpg
# filename: video_syn_result/6/wall/0_220.0.jpg
# filename: video_syn_result/6/wall/0_221.0.jpg
# filename: video_syn_result/6/wall/0_222.0.jpg
# filename: video_syn_result/6/wall/0_223.0.jpg
# filename: video_syn_result/6/wall/0_224.0.jpg
# filename: video_syn_result/6/wall/0_225.0.jpg
# filename: video_syn_result/6/wall/0_226.0.jpg
# filename: video_syn_result/6/wall/0_227.0.jpg
# filename: video_syn_result/6/wall/0_228.0.jpg
# filename: video_syn_result/6/wall/0_229.0.jpg
# filename: video_syn_result/6/wall/0_230.0.jpg
# filename: video_syn_result/6/wall/0_231.0.jpg
# filename: video_syn_result/6/wall/0_232.0.jpg
# filename: video_syn_result/6/wall/0_233.0.jpg
# filename: video_syn_result/6/wall/0_234.0.jpg
# filename: video_syn_result/6/wall/0_235.0.jpg
# filename: video_syn_result/6/wall/0_236.0.jpg
# filename: video_syn_result/6/wall/0_237.0.jpg
# filename: video_syn_result/6/wall/0_238.0.jpg
# filename: video_syn_result/6/wall/0_239.0.jpg
# filename: video_syn_result/6/wall/0_240.0.jpg
# filename: video_syn_result/6/wall/0_241.0.jpg
# filename: video_syn_result/6/wall/0_242.0.jpg
# filename: video_syn_result/6/wall/0_243.0.jpg
# filename: video_syn_result/6/wall/0_244.0.jpg
# filename: video_syn_result/6/wall/0_245.0.jpg
# filename: video_syn_result/6/wall/0_246.0.jpg
# filename: video_syn_result/6/wall/0_247.0.jpg
# filename: video_syn_result/6/wall/0_248.0.jpg
# filename: video_syn_result/6/wall/0_249.0.jpg
# filename: video_syn_result/6/wall/0_250.0.jpg
# filename: video_syn_result/6/wall/0_251.0.jpg
# filename: video_syn_result/6/wall/0_252.0.jpg
# filename: video_syn_result/6/wall/0_253.0.jpg
# filename: video_syn_result/6/wall/0_254.0.jpg
# filename: video_syn_result/6/wall/0_255.0.jpg
# filename: video_syn_result/6/wall/0_256.0.jpg
# filename: video_syn_result/6/wall/0_257.0.jpg
# filename: video_syn_result/6/wall/0_258.0.jpg
# filename: video_syn_result/6/wall/0_259.0.jpg
# filename: video_syn_result/6/wall/0_260.0.jpg
# filename: video_syn_result/6/wall/0_261.0.jpg
# filename: video_syn_result/6/wall/0_262.0.jpg
# filename: video_syn_result/6/wall/0_263.0.jpg
# filename: video_syn_result/6/wall/0_264.0.jpg
# filename: video_syn_result/6/wall/0_265.0.jpg
# filename: video_syn_result/6/wall/0_266.0.jpg
# filename: video_syn_result/6/wall/0_267.0.jpg
# filename: video_syn_result/6/wall/0_268.0.jpg
# filename: video_syn_result/6/wall/0_269.0.jpg
# filename: video_syn_result/6/wall/0_270.0.jpg
# filename: video_syn_result/6/wall/0_271.0.jpg
# filename: video_syn_result/6/wall/0_272.0.jpg
# filename: video_syn_result/6/wall/0_273.0.jpg
# filename: video_syn_result/6/wall/0_274.0.jpg
# filename: video_syn_result/6/wall/0_275.0.jpg
# filename: video_syn_result/6/wall/0_276.0.jpg
# filename: video_syn_result/6/wall/0_277.0.jpg
# filename: video_syn_result/6/wall/0_278.0.jpg
# filename: video_syn_result/6/wall/0_279.0.jpg
# filename: video_syn_result/6/wall/0_280.0.jpg
# filename: video_syn_result/6/wall/0_281.0.jpg
# filename: video_syn_result/6/wall/0_282.0.jpg
# filename: video_syn_result/6/wall/0_283.0.jpg
# filename: video_syn_result/6/wall/0_284.0.jpg
# filename: video_syn_result/6/wall/0_285.0.jpg
# filename: video_syn_result/6/wall/0_286.0.jpg
# filename: video_syn_result/6/wall/0_287.0.jpg
# filename: video_syn_result/6/wall/0_288.0.jpg
# filename: video_syn_result/6/wall/0_289.0.jpg
# filename: video_syn_result/6/wall/0_290.0.jpg
# filename: video_syn_result/6/wall/0_291.0.jpg
# filename: video_syn_result/6/wall/0_292.0.jpg
# filename: video_syn_result/6/wall/0_293.0.jpg
# filename: video_syn_result/6/wall/0_294.0.jpg
# filename: video_syn_result/6/wall/0_295.0.jpg
# filename: video_syn_result/6/wall/0_296.0.jpg
# filename: video_syn_result/6/wall/0_297.0.jpg
# filename: video_syn_result/6/wall/0_298.0.jpg
# filename: video_syn_result/6/wall/0_299.0.jpg
# filename: video_syn_result/6/wall/0_300.0.jpg
# filename: video_syn_result/6/wall/0_301.0.jpg
# filename: video_syn_result/6/wall/0_302.0.jpg
# filename: video_syn_result/6/wall/0_303.0.jpg
# filename: video_syn_result/6/wall/0_304.0.jpg
# filename: video_syn_result/6/wall/0_305.0.jpg
# filename: video_syn_result/6/wall/0_306.0.jpg
# filename: video_syn_result/6/wall/0_307.0.jpg
# filename: video_syn_result/6/wall/0_308.0.jpg
# filename: video_syn_result/6/wall/0_309.0.jpg
# filename: video_syn_result/6/wall/0_310.0.jpg
# filename: video_syn_result/6/wall/0_311.0.jpg
# filename: video_syn_result/6/wall/0_312.0.jpg
# filename: video_syn_result/6/wall/0_313.0.jpg
# filename: video_syn_result/6/wall/0_314.0.jpg
# filename: video_syn_result/6/wall/0_315.0.jpg
# filename: video_syn_result/6/wall/0_316.0.jpg
# filename: video_syn_result/6/wall/0_317.0.jpg
# filename: video_syn_result/6/wall/0_318.0.jpg
# filename: video_syn_result/6/wall/0_319.0.jpg
# filename: video_syn_result/6/wall/0_320.0.jpg
# filename: video_syn_result/6/wall/0_321.0.jpg
# filename: video_syn_result/6/wall/0_322.0.jpg
# filename: video_syn_result/6/wall/0_323.0.jpg
# filename: video_syn_result/6/wall/0_324.0.jpg
# filename: video_syn_result/6/wall/0_325.0.jpg
# filename: video_syn_result/6/wall/0_326.0.jpg
# filename: video_syn_result/6/wall/0_327.0.jpg
# filename: video_syn_result/6/wall/0_328.0.jpg
# filename: video_syn_result/6/wall/0_329.0.jpg
# filename: video_syn_result/6/wall/0_330.0.jpg
# filename: video_syn_result/6/wall/0_331.0.jpg
# filename: video_syn_result/6/wall/0_332.0.jpg
# filename: video_syn_result/6/wall/0_333.0.jpg
# filename: video_syn_result/6/wall/0_334.0.jpg
# filename: video_syn_result/6/wall/0_335.0.jpg
# filename: video_syn_result/6/wall/0_336.0.jpg
# filename: video_syn_result/6/wall/0_337.0.jpg
# filename: video_syn_result/6/wall/0_338.0.jpg
# filename: video_syn_result/6/wall/0_339.0.jpg
# filename: video_syn_result/6/wall/0_340.0.jpg
# filename: video_syn_result/6/wall/0_341.0.jpg
# filename: video_syn_result/6/wall/0_342.0.jpg
# filename: video_syn_result/6/wall/0_343.0.jpg
# filename: video_syn_result/6/wall/0_344.0.jpg
# filename: video_syn_result/6/wall/0_345.0.jpg
# filename: video_syn_result/6/wall/0_346.0.jpg
# filename: video_syn_result/6/wall/0_347.0.jpg
# filename: video_syn_result/6/wall/0_348.0.jpg
# filename: video_syn_result/6/wall/0_349.0.jpg
# filename: video_syn_result/6/wall/0_350.0.jpg
# filename: video_syn_result/6/wall/0_351.0.jpg
# filename: video_syn_result/6/wall/0_352.0.jpg
# filename: video_syn_result/6/wall/0_353.0.jpg
# filename: video_syn_result/6/wall/0_354.0.jpg
# filename: video_syn_result/6/wall/0_355.0.jpg
# filename: video_syn_result/6/wall/0_356.0.jpg
# filename: video_syn_result/6/wall/0_357.0.jpg
# filename: video_syn_result/6/wall/0_358.0.jpg
# filename: video_syn_result/6/wall/0_359.0.jpg
# filename: video_syn_result/6/wall/0_360.0.jpg
# filename: video_syn_result/6/wall/0_361.0.jpg
# filename: video_syn_result/6/wall/0_362.0.jpg
# filename: video_syn_result/6/wall/0_363.0.jpg
# filename: video_syn_result/6/wall/0_364.0.jpg
# filename: video_syn_result/6/wall/0_365.0.jpg
# filename: video_syn_result/6/wall/0_366.0.jpg
# filename: video_syn_result/6/wall/0_367.0.jpg
# filename: video_syn_result/6/wall/0_368.0.jpg
# filename: video_syn_result/6/wall/0_369.0.jpg
# filename: video_syn_result/6/wall/0_370.0.jpg
# filename: video_syn_result/6/wall/0_371.0.jpg
# filename: video_syn_result/6/wall/0_372.0.jpg
# filename: video_syn_result/6/wall/0_373.0.jpg
# filename: video_syn_result/6/wall/0_374.0.jpg
# filename: video_syn_result/6/wall/0_375.0.jpg
# filename: video_syn_result/6/wall/0_376.0.jpg
# filename: video_syn_result/6/wall/0_377.0.jpg
# filename: video_syn_result/6/wall/0_378.0.jpg
# filename: video_syn_result/6/wall/0_379.0.jpg
# filename: video_syn_result/6/wall/0_380.0.jpg
# filename: video_syn_result/6/wall/0_381.0.jpg
# filename: video_syn_result/6/wall/0_382.0.jpg
# filename: video_syn_result/6/wall/0_383.0.jpg
# filename: video_syn_result/6/wall/0_384.0.jpg
# filename: video_syn_result/6/wall/0_385.0.jpg
# filename: video_syn_result/6/wall/0_386.0.jpg
# filename: video_syn_result/6/wall/0_387.0.jpg
# filename: video_syn_result/6/wall/0_388.0.jpg
# filename: video_syn_result/6/wall/0_389.0.jpg
# filename: video_syn_result/6/wall/0_390.0.jpg
# filename: video_syn_result/6/wall/0_391.0.jpg
# filename: video_syn_result/6/wall/0_392.0.jpg
# filename: video_syn_result/6/wall/0_393.0.jpg
# filename: video_syn_result/6/wall/0_394.0.jpg
# filename: video_syn_result/6/wall/0_395.0.jpg
# filename: video_syn_result/6/wall/0_396.0.jpg
# filename: video_syn_result/6/wall/0_397.0.jpg
# filename: video_syn_result/6/wall/0_398.0.jpg
# filename: video_syn_result/6/wall/0_399.0.jpg
# filename: video_syn_result/6/wall/0_400.0.jpg
# filename: video_syn_result/6/wall/0_401.0.jpg
# filename: video_syn_result/6/wall/0_402.0.jpg
# filename: video_syn_result/6/wall/0_403.0.jpg
# filename: video_syn_result/6/wall/0_404.0.jpg
# filename: video_syn_result/6/wall/0_405.0.jpg
# filename: video_syn_result/6/wall/0_406.0.jpg
# filename: video_syn_result/6/wall/0_407.0.jpg
# filename: video_syn_result/6/wall/0_408.0.jpg
# filename: video_syn_result/6/wall/0_409.0.jpg
# filename: video_syn_result/6/wall/0_410.0.jpg
# filename: video_syn_result/6/wall/0_411.0.jpg
# filename: video_syn_result/6/wall/0_412.0.jpg
# filename: video_syn_result/6/wall/0_413.0.jpg
# filename: video_syn_result/6/wall/0_414.0.jpg
# filename: video_syn_result/6/wall/0_415.0.jpg
# filename: video_syn_result/6/wall/0_416.0.jpg
# filename: video_syn_result/6/wall/0_417.0.jpg
# filename: video_syn_result/6/wall/0_418.0.jpg
# filename: video_syn_result/6/wall/0_419.0.jpg
# filename: video_syn_result/6/wall/0_420.0.jpg
# filename: video_syn_result/6/wall/0_421.0.jpg
# filename: video_syn_result/6/wall/0_422.0.jpg
# filename: video_syn_result/6/wall/0_423.0.jpg
# filename: video_syn_result/6/wall/0_424.0.jpg
# filename: video_syn_result/6/wall/0_425.0.jpg
# filename: video_syn_result/6/wall/0_426.0.jpg
# filename: video_syn_result/6/wall/0_427.0.jpg
# filename: video_syn_result/6/wall/0_428.0.jpg
# filename: video_syn_result/6/wall/0_429.0.jpg
# filename: video_syn_result/6/wall/0_430.0.jpg
# filename: video_syn_result/6/wall/0_431.0.jpg
# filename: video_syn_result/6/wall/0_432.0.jpg
# filename: video_syn_result/6/wall/0_433.0.jpg
# filename: video_syn_result/6/wall/0_434.0.jpg
# filename: video_syn_result/6/wall/0_435.0.jpg
# filename: video_syn_result/6/wall/0_436.0.jpg
# filename: video_syn_result/6/wall/0_437.0.jpg
# filename: video_syn_result/6/wall/0_438.0.jpg
# filename: video_syn_result/6/wall/0_439.0.jpg
# filename: video_syn_result/6/wall/0_440.0.jpg
# filename: video_syn_result/6/wall/0_441.0.jpg
# filename: video_syn_result/6/wall/0_442.0.jpg
# filename: video_syn_result/6/wall/0_443.0.jpg
# filename: video_syn_result/6/wall/0_444.0.jpg
# filename: video_syn_result/6/wall/0_445.0.jpg
# filename: video_syn_result/6/wall/0_446.0.jpg
# filename: video_syn_result/6/wall/0_447.0.jpg
# filename: video_syn_result/6/wall/0_448.0.jpg
# filename: video_syn_result/6/wall/0_449.0.jpg
# filename: video_syn_result/6/wall/0_450.0.jpg
# filename: video_syn_result/6/wall/0_451.0.jpg
# filename: video_syn_result/6/wall/0_452.0.jpg
# filename: video_syn_result/6/wall/0_453.0.jpg
# filename: video_syn_result/6/wall/0_454.0.jpg
# filename: video_syn_result/6/wall/0_455.0.jpg
# filename: video_syn_result/6/wall/0_456.0.jpg
# filename: video_syn_result/6/wall/0_457.0.jpg
# filename: video_syn_result/6/wall/0_458.0.jpg
# filename: video_syn_result/6/wall/0_459.0.jpg
# filename: video_syn_result/6/wall/0_460.0.jpg
# filename: video_syn_result/6/wall/0_461.0.jpg
# filename: video_syn_result/6/wall/0_462.0.jpg
# filename: video_syn_result/6/wall/0_463.0.jpg
# filename: video_syn_result/6/wall/0_464.0.jpg
# filename: video_syn_result/6/wall/0_465.0.jpg
# filename: video_syn_result/6/wall/0_466.0.jpg
# filename: video_syn_result/6/wall/0_467.0.jpg
# filename: video_syn_result/6/wall/0_468.0.jpg
# filename: video_syn_result/6/wall/0_469.0.jpg
# filename: video_syn_result/6/wall/0_470.0.jpg
# filename: video_syn_result/6/wall/0_471.0.jpg
# filename: video_syn_result/6/wall/0_472.0.jpg
# filename: video_syn_result/6/wall/0_473.0.jpg
# filename: video_syn_result/6/wall/0_474.0.jpg
# filename: video_syn_result/6/wall/0_475.0.jpg
# filename: video_syn_result/6/wall/0_476.0.jpg
# filename: video_syn_result/6/wall/0_477.0.jpg
# filename: video_syn_result/6/wall/0_478.0.jpg
# filename: video_syn_result/6/wall/0_479.0.jpg
# filename: video_syn_result/6/wall/0_480.0.jpg
# filename: video_syn_result/6/wall/0_481.0.jpg
# filename: video_syn_result/6/wall/0_482.0.jpg
# filename: video_syn_result/6/wall/0_483.0.jpg
# filename: video_syn_result/6/wall/0_484.0.jpg
# filename: video_syn_result/6/wall/0_485.0.jpg
# filename: video_syn_result/6/wall/0_486.0.jpg
# filename: video_syn_result/6/wall/0_487.0.jpg
# filename: video_syn_result/6/wall/0_488.0.jpg
# filename: video_syn_result/6/wall/0_489.0.jpg
# filename: video_syn_result/6/wall/0_490.0.jpg
# filename: video_syn_result/6/wall/0_491.0.jpg
# filename: video_syn_result/6/wall/0_492.0.jpg
# filename: video_syn_result/6/wall/0_493.0.jpg
# filename: video_syn_result/6/wall/0_494.0.jpg
# filename: video_syn_result/6/wall/0_495.0.jpg
# filename: video_syn_result/6/wall/0_496.0.jpg
# filename: video_syn_result/6/wall/0_497.0.jpg
# filename: video_syn_result/6/wall/0_498.0.jpg
# filename: video_syn_result/6/wall/0_499.0.jpg
# filename: video_syn_result/6/wall/0_500.0.jpg
# filename: video_syn_result/6/wall/0_501.0.jpg
# filename: video_syn_result/6/wall/0_502.0.jpg
# filename: video_syn_result/6/wall/0_503.0.jpg
# filename: video_syn_result/6/wall/0_504.0.jpg
# filename: video_syn_result/6/wall/0_505.0.jpg
# filename: video_syn_result/6/wall/0_506.0.jpg
# filename: video_syn_result/6/wall/0_507.0.jpg
# filename: video_syn_result/6/wall/0_508.0.jpg
# filename: video_syn_result/6/wall/0_509.0.jpg
# filename: video_syn_result/6/wall/0_510.0.jpg
# filename: video_syn_result/6/wall/0_511.0.jpg
# filename: video_syn_result/6/wall/0_512.0.jpg
# filename: video_syn_result/6/wall/0_513.0.jpg
# filename: video_syn_result/6/wall/0_514.0.jpg
# filename: video_syn_result/6/wall/0_515.0.jpg
# filename: video_syn_result/6/wall/0_516.0.jpg
# filename: video_syn_result/6/wall/0_517.0.jpg
# filename: video_syn_result/6/wall/0_518.0.jpg
# filename: video_syn_result/6/wall/0_519.0.jpg
# filename: video_syn_result/6/wall/0_520.0.jpg
# filename: video_syn_result/6/wall/0_521.0.jpg
# filename: video_syn_result/6/wall/0_522.0.jpg
# filename: video_syn_result/6/wall/0_523.0.jpg
# filename: video_syn_result/6/wall/0_524.0.jpg
# filename: video_syn_result/6/wall/0_525.0.jpg
# filename: video_syn_result/6/wall/0_526.0.jpg
# filename: video_syn_result/6/wall/0_527.0.jpg
# filename: video_syn_result/6/wall/0_528.0.jpg
# filename: video_syn_result/6/wall/0_529.0.jpg
# filename: video_syn_result/6/wall/0_530.0.jpg
# filename: video_syn_result/6/wall/0_531.0.jpg
# filename: video_syn_result/6/wall/0_532.0.jpg
# filename: video_syn_result/6/wall/0_533.0.jpg
# filename: video_syn_result/6/wall/0_534.0.jpg
# filename: video_syn_result/6/wall/0_535.0.jpg
# filename: video_syn_result/6/wall/0_536.0.jpg
# filename: video_syn_result/6/wall/0_537.0.jpg
# filename: video_syn_result/6/wall/0_538.0.jpg
# filename: video_syn_result/6/wall/0_539.0.jpg
# filename: video_syn_result/6/wall/0_540.0.jpg
# filename: video_syn_result/6/wall/0_541.0.jpg
# filename: video_syn_result/6/wall/0_542.0.jpg
# filename: video_syn_result/6/wall/0_543.0.jpg
# filename: video_syn_result/6/wall/0_544.0.jpg
# filename: video_syn_result/6/wall/0_545.0.jpg
# filename: video_syn_result/6/wall/0_546.0.jpg
# filename: video_syn_result/6/wall/0_547.0.jpg
# filename: video_syn_result/6/wall/0_548.0.jpg
# filename: video_syn_result/6/wall/0_549.0.jpg
# filename: video_syn_result/6/wall/0_550.0.jpg
# filename: video_syn_result/6/wall/0_551.0.jpg
# filename: video_syn_result/6/wall/0_552.0.jpg
# filename: video_syn_result/6/wall/0_553.0.jpg
# filename: video_syn_result/6/wall/0_554.0.jpg
# filename: video_syn_result/6/wall/0_555.0.jpg
# filename: video_syn_result/6/wall/0_556.0.jpg
# filename: video_syn_result/6/wall/0_557.0.jpg
# filename: video_syn_result/6/wall/0_558.0.jpg
# filename: video_syn_result/6/wall/0_559.0.jpg
# filename: video_syn_result/6/wall/0_560.0.jpg
# filename: video_syn_result/6/wall/0_561.0.jpg
# filename: video_syn_result/6/wall/0_562.0.jpg
# filename: video_syn_result/6/wall/0_563.0.jpg
# filename: video_syn_result/6/wall/0_564.0.jpg
# filename: video_syn_result/6/wall/0_565.0.jpg
# filename: video_syn_result/6/wall/0_566.0.jpg
# filename: video_syn_result/6/wall/0_567.0.jpg
# filename: video_syn_result/6/wall/0_568.0.jpg
# filename: video_syn_result/6/wall/0_569.0.jpg
# filename: video_syn_result/6/wall/0_570.0.jpg
# filename: video_syn_result/6/wall/0_571.0.jpg
# filename: video_syn_result/6/wall/0_572.0.jpg
# filename: video_syn_result/6/wall/0_573.0.jpg
# filename: video_syn_result/6/wall/0_574.0.jpg
# filename: video_syn_result/6/wall/0_575.0.jpg
# filename: video_syn_result/6/wall/0_576.0.jpg
# filename: video_syn_result/6/wall/0_577.0.jpg
# filename: video_syn_result/6/wall/0_578.0.jpg
# filename: video_syn_result/6/wall/0_579.0.jpg
# filename: video_syn_result/6/wall/0_580.0.jpg
# filename: video_syn_result/6/wall/0_581.0.jpg
# filename: video_syn_result/6/wall/0_582.0.jpg
# filename: video_syn_result/6/wall/0_583.0.jpg
# filename: video_syn_result/6/wall/0_584.0.jpg
# filename: video_syn_result/6/wall/0_585.0.jpg
# filename: video_syn_result/6/wall/0_586.0.jpg
# filename: video_syn_result/6/wall/0_587.0.jpg
# filename: video_syn_result/6/wall/0_588.0.jpg
# filename: video_syn_result/6/wall/0_589.0.jpg
# filename: video_syn_result/6/wall/0_590.0.jpg
# filename: video_syn_result/6/wall/0_591.0.jpg
# filename: video_syn_result/6/wall/0_592.0.jpg
# filename: video_syn_result/6/wall/0_593.0.jpg
# filename: video_syn_result/6/wall/0_594.0.jpg
# filename: video_syn_result/6/wall/0_595.0.jpg
# filename: video_syn_result/6/wall/0_596.0.jpg
# filename: video_syn_result/6/wall/0_597.0.jpg
# filename: video_syn_result/6/wall/0_598.0.jpg
# filename: video_syn_result/6/wall/0_599.0.jpg
# filename: video_syn_result/6/wall/0_600.0.jpg
# filename: video_syn_result/6/wall/0_601.0.jpg
# filename: video_syn_result/6/wall/0_602.0.jpg
# filename: video_syn_result/6/wall/0_603.0.jpg
# filename: video_syn_result/6/wall/0_604.0.jpg
# filename: video_syn_result/6/wall/0_605.0.jpg
# filename: video_syn_result/6/wall/0_606.0.jpg
# filename: video_syn_result/6/wall/0_607.0.jpg
# filename: video_syn_result/6/wall/0_608.0.jpg
# filename: video_syn_result/6/wall/0_609.0.jpg
# filename: video_syn_result/6/wall/0_610.0.jpg
# filename: video_syn_result/6/wall/0_611.0.jpg
# filename: video_syn_result/6/wall/0_612.0.jpg
# filename: video_syn_result/6/wall/0_613.0.jpg
# filename: video_syn_result/6/wall/0_614.0.jpg
# filename: video_syn_result/6/wall/0_615.0.jpg
# filename: video_syn_result/6/wall/0_616.0.jpg
# filename: video_syn_result/6/wall/0_617.0.jpg
# filename: video_syn_result/6/wall/0_618.0.jpg
# filename: video_syn_result/6/wall/0_619.0.jpg
# filename: video_syn_result/6/wall/0_620.0.jpg
# filename: video_syn_result/6/wall/0_621.0.jpg
# filename: video_syn_result/6/wall/0_622.0.jpg
# filename: video_syn_result/6/wall/0_623.0.jpg
# filename: video_syn_result/6/wall/0_624.0.jpg
# filename: video_syn_result/6/wall/0_625.0.jpg
# filename: video_syn_result/6/wall/0_626.0.jpg
# filename: video_syn_result/6/wall/0_627.0.jpg
# filename: video_syn_result/6/wall/0_628.0.jpg
# filename: video_syn_result/6/wall/0_629.0.jpg
# filename: video_syn_result/6/wall/0_630.0.jpg
# filename: video_syn_result/6/wall/0_631.0.jpg
# filename: video_syn_result/6/wall/0_632.0.jpg
# filename: video_syn_result/6/wall/0_633.0.jpg
# filename: video_syn_result/6/wall/0_634.0.jpg
# filename: video_syn_result/6/wall/0_635.0.jpg
# filename: video_syn_result/6/wall/0_636.0.jpg
# filename: video_syn_result/6/wall/0_637.0.jpg
# filename: video_syn_result/6/wall/0_638.0.jpg
# filename: video_syn_result/6/wall/0_639.0.jpg
# filename: video_syn_result/6/wall/0_640.0.jpg
# filename: video_syn_result/6/wall/0_641.0.jpg

# %% [markdown]
# ### Warp Affine

# %%
import imutils

for mask in os.listdir(mask_path):
  # print(mask)

  # mask_img = cv2.imread(mask_path + mask)
  mask_img = Image.open(mask_path + mask)
  org, mask_img = np.split(np.array(mask_img), 2, axis=1)
  mask_img = mask_img[:mask_img.shape[0] - 10, :mask_img.shape[1] - 10]
  # plt.imshow(mask_img)
  # plt.show()

  gray = cv2.cvtColor(mask_img, cv2.COLOR_RGB2GRAY)
  # gray = cv2.cvtColor(mask_img.astype(np.float32), cv2.COLOR_RGB2GRAY) * 255
  ret, thr = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
  # thr = thr.astype(np.uint8)
  # print(thr.shape)
  # print(thr.dtype)
  # print(thr.max())
  # print(thr.astype(np.uint8))

  contours, _ = cv2.findContours(thr, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  # print(contours.shape)

  #          Find Max Height Contour Point       #
  # max_height_point = np.array([[mask_img.shape[0], mask_img.shape[1]]])
  max_height_point = np.array([[0, 0]])
  # print(max_height_point)
  for contour in contours:
    # print(contour.shape)
    for point in contour:
      # print(point[0][1], max_height_point[0][1])
      # if 0 < point[0][1] <= max_height_point[0][1]:
      if point[0][1] >= max_height_point[0][1]:
        # print(max_height_point[0][1])
        # print('point[0][1] >= max_height_point[0][1] :', point[0][1] >= max_height_point[0][1])
        max_height_point = point
      # print(point)
      # break
    ctr = contour.astype(np.int32)
    cv2.drawContours(mask_img, [ctr], -1, (255, 0, 0), 5)
    # hull = cv2.convexHull(contour, clockwise=False)
    # cv2.drawContours(mask_img, [hull], -1, (255, 0, 0), 5)
    # break
  # print(max_height_point)
  cv2.circle(mask_img, (max_height_point[0][0], max_height_point[0][1]), 10, (255, 255, 0), -1)

  # x, y, w, h = cv2.boundingRect(contours[0])
  # print(x, y)
  # rect = cv2.minAreaRect(contours[0])
  # box = cv2.boxPoints(rect)
  # box = box.astype('int')

  # contours = imutils.grab_contours(contours)
  # c = max(contours, key=cv2.contourArea)
  # draw the contours of c
  # cv2.drawContours(image, [c], -1, (0, 0, 255), 2)

  epsilon1 = 0.03 * cv2.arcLength(contours[0], True)
  approx1 = cv2.approxPolyDP(contours[0], epsilon1, True)

  # cv2.drawContours(mask_img, [approx1], 0, (255, 255, 0), 5)
  # cv2.drawContours(mask_img, [box], 0, (255, 0, 0), 5)
  # cv2.drawContours(mask_img, [contours[0]], 0, (255, 0, 0), 5)

  # cv2.rectangle(mask_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
  #       Warping       #
  pts1 = np.float32([[max_height_point[0][0], max_height_point[0][1]], [0, 0], [gray.shape[1], 0]])
  pts2 = np.float32([[max_height_point[0][0], gray.shape[0]], [0, 0], [gray.shape[1], 0]])
  print(pts1, pts2)
  print(max_height_point)

  matrix = cv2.getAffineTransform(pts2, pts1)

  refer_image = '5f0f768b52b5fa3fd09c48e5b6409a09.jpg'
  refer = Image.open(refer_path + refer_image)
  refer = refer.resize(img_size)

  plt.imshow(refer)
  plt.show()
  refer = np.asarray(refer)
  refer = cv2.warpAffine(refer, matrix, (refer.shape[1], refer.shape[0]))


  # thr = cv2.cvtColor(thr, cv2.COLOR_GRAY2RGB)
  # plt.imshow(final_img)
  # plt.imshow(thr)
  plt.imshow(mask_img)
  # plt.imshow(gray)
  # plt.axis('off')
  plt.show()
  plt.imshow(refer)
  plt.show()
  break
# Out:
# [[476. 161.]
#  [  0.   0.]
#  [710.   0.]] [[476. 470.]
#  [  0.   0.]
#  [710.   0.]]
# [[476 161]]

# %% [markdown]
# ### Data Moving

# %%
import shutil
import os

video_path = './video_result/2/'
video_list = os.listdir(video_path)
print(len(video_list))

for video in video_list:
  if not video.endswith('.png'):
    continue

  try:
  shutil.move(video_path + video, video_path + 'wall/' + video)

# %%
import random 

# rand_refer_list = random.sample([1, 2, 3, 4, 5, 6, 7, 8, 9], 5)
# print(rand_refer_list)

w, h  = 256, 256

import numpy as np

color_number_list = np.arange(256)
# print(color_number_list)
rand_color = list()
for i in range(3):
  rand_color.append(random.choice(color_number_list))

rand_color = np.array(rand_color).reshape(1, -1)
print(rand_color)

refer = np.tile(rand_color, (w, h, 1))
# print(refer)

import matplotlib.pyplot as plt

plt.imshow(refer)
plt.show()
# print([i for i in )

print(np.arange(1, 4))
# Out:
# [[208 206 206]]
# [1 2 3]
