# %%
current_path = '/content/drive/My Drive/Colab Notebooks/Project_GANder/gankook_cuda/semantic-segmentation-pytorch/'

import os

os.chdir(current_path)
# !ls
# Out:
#  ade20k-resnet50dilated-ppm_deepsup   __pycache__
#  batch_tensor			      pytorch_refinenet
#  Building_images		      Pytorch-UNet
#  ckpt				      README.md
# 'Color Synthetic.ipynb'		      refer_data
#  config				      requirements.txt
#  data				      result_data
#  decoder_tensor_image.png	      setup.py
#  demo_test.sh			      SSP.ipynb
#  download_ADE20K.sh		      SSP_plus_weights_Ceiling.ipynb
#  DrivingLaneDetection		      SSP_plus_weights_Floor.ipynb
#  edge_tensor			      SSP_plus_weights_Tester.ipynb
#  edge_tensor_image.png		      SSP_plus_weights_Wall.ipynb
#  encoder_tensor_image.png	      syn_result
#  eval_multipro.py		      teaser
#  eval.py			      tensor_image.png
#  LICENSE			      test_data
#  mask_data			      test.py
#  mit_semseg			      test_result
#  pretrained			      train.py

# %%
# !sudo pip install yacs
# Out:
# Collecting yacs
#   Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from yacs) (3.13)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8

# %%
# !chmod +x demo_test.sh
# !./demo_test.sh

# %%
# !nvidia-smi

# %%
# !pip install tensorboardX
# !tensorboard --logdir runs

# %%
from scipy.io import loadmat, savemat

colors_ = loadmat('data/color150.mat')['colors']
colors = loadmat('data/wall150.mat')['colors']
print(type(colors_[0][0]))
print(type(colors[0][0]))
# Out:
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>

# %%
import pandas as pd
import numpy as np

colors_csv = pd.read_csv('data/color_coding_semantic_segmentation_classes.csv', index_col=0)
colors_csv = colors_csv['Color_Code (R,G,B)'] 

for i in range(len(colors_csv)):
  if i == 0:
    colors_csv.iloc[i] = [255, 255, 255] #.astype('uint8')
  else:
    colors_csv.iloc[i] = [0, 0, 0] #.astype('uint8')

colors_csv = np.array(colors_csv.tolist()).astype('uint8')
print(colors_csv)

savemat('data/wall150.mat', mdict={'colors': colors_csv})

# %% [markdown]
# ## Train Model

# %%
# %matplotlib inline


# !python3 train.py --gpus 0 --cfg config/ade20k-resnet101-upernet.yaml \
# !python3 train.py --gpus 0 --cfg config/ade20k-hrnetv2.yaml \
DATASET.list_train "./data/selected_training.odgt" DATASET.list_val "./data/selected_validation.odgt" \
MODEL.object_index 5 \
TRAIN.batch_size_per_gpu 4 \
TRAIN.start_epoch 17 \
TRAIN.load_unet False \
VAL.batch_size 4
# TRAIN.start_epoch 50 \
# TRAIN.num_epoch 60
# Out:
# [2020-08-20 03:14:52,620 INFO train.py line 344 3482] Loaded configuration file config/ade20k-hrnetv2.yaml
# [2020-08-20 03:14:52,620 INFO train.py line 345 3482] Running with config:
# DATASET:
#   imgMaxSize: 1000
#   imgSizes: (300, 375, 450, 525, 600)
#   list_train: ./data/selected_training.odgt
#   list_val: ./data/selected_validation.odgt
#   num_class: 150
#   padding_constant: 32
#   random_flip: True
#   root_dataset: ./data/
#   segm_downsampling_rate: 4
# DIR: ckpt/ade20k-hrnetv2-c1
# MODEL:
#   arch_decoder: c1
#   arch_encoder: hrnetv2
#   fc_dim: 720
#   object_index: 5
#   weights_decoder:
#   weights_encoder:
#   weights_unet:
# TEST:
#   batch_size: 1
#   checkpoint: epoch_30.pth
#   result: ./
# TRAIN:
#   batch_size_per_gpu: 4
#   beta1: 0.9
#   deep_sup_scale: 0.4
#   disp_iter: 20
#   epoch_iters: 5000
#   fix_bn: False
#   load_unet: False
#   lr_decoder: 0.02
#   lr_encoder: 0.02
#   lr_pow: 0.9
#   lr_unet: 0.02
#   num_epoch: 30
#   optim: SGD
#   seed: 304
#   start_epoch: 17
#   weight_decay: 0.0001
#   workers: 16
# VAL:
#   batch_size: 4
#   checkpoint: epoch_30.pth
#   visualize: False
# [2020-08-20 03:14:52,620 INFO train.py line 350 3482] Outputing checkpoints to: ckpt/ade20k-hrnetv2-c1
# Loading weights for net_encoder
# Loading weights for net_decoder
# # samples: 3530
# # samples: 685
# 1 Epoch = 5000 iters
# 100% 171/171 [01:56<00:00,  1.57it/s][Eval Summary]:
# Accuracy: 0.00%, Inference Time: 0.6016s
# Epoch: [18][0/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009423, lr_decoder: 0.009423, Accuracy: 97.71, Accuracy_Binary: 41.33, Loss: 0.848965
# Epoch: [18][20/5000], Time: 0.62, Data: 0.00, lr_encoder: 0.009420, lr_decoder: 0.009420, Accuracy: 97.55, Accuracy_Binary: 92.40, Loss: 0.283648
# Epoch: [18][40/5000], Time: 0.69, Data: 0.00, lr_encoder: 0.009417, lr_decoder: 0.009417, Accuracy: 97.63, Accuracy_Binary: 95.70, Loss: 0.191163
# Epoch: [18][60/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009415, lr_decoder: 0.009415, Accuracy: 97.65, Accuracy_Binary: 96.85, Loss: 0.157594
# Epoch: [18][80/5000], Time: 0.74, Data: 0.00, lr_encoder: 0.009412, lr_decoder: 0.009412, Accuracy: 97.59, Accuracy_Binary: 97.32, Loss: 0.145155
# Epoch: [18][100/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009410, lr_decoder: 0.009410, Accuracy: 97.57, Accuracy_Binary: 97.60, Loss: 0.137571
# Epoch: [18][120/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009407, lr_decoder: 0.009407, Accuracy: 97.55, Accuracy_Binary: 97.89, Loss: 0.129886
# Epoch: [18][140/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009404, lr_decoder: 0.009404, Accuracy: 97.55, Accuracy_Binary: 98.08, Loss: 0.124370
# Epoch: [18][160/5000], Time: 0.74, Data: 0.00, lr_encoder: 0.009402, lr_decoder: 0.009402, Accuracy: 97.54, Accuracy_Binary: 98.20, Loss: 0.121043
# Epoch: [18][520/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009355, lr_decoder: 0.009355, Accuracy: 97.65, Accuracy_Binary: 98.90, Loss: 0.096323
# Epoch: [18][540/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009352, lr_decoder: 0.009352, Accuracy: 97.66, Accuracy_Binary: 98.92, Loss: 0.095639
# Epoch: [18][560/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009349, lr_decoder: 0.009349, Accuracy: 97.66, Accuracy_Binary: 98.94, Loss: 0.095014
# Epoch: [18][580/5000], Time: 0.71, Data: 0.00, lr_encoder: 0.009347, lr_decoder: 0.009347, Accuracy: 97.66, Accuracy_Binary: 98.95, Loss: 0.094460
# Epoch: [18][600/5000], Time: 0.71, Data: 0.00, lr_encoder: 0.009344, lr_decoder: 0.009344, Accuracy: 97.66, Accuracy_Binary: 98.96, Loss: 0.094057
# Epoch: [18][620/5000], Time: 0.71, Data: 0.00, lr_encoder: 0.009342, lr_decoder: 0.009342, Accuracy: 97.65, Accuracy_Binary: 98.98, Loss: 0.093680
# Epoch: [18][640/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009339, lr_decoder: 0.009339, Accuracy: 97.65, Accuracy_Binary: 99.00, Loss: 0.093243
# Epoch: [18][660/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009336, lr_decoder: 0.009336, Accuracy: 97.66, Accuracy_Binary: 99.01, Loss: 0.092670
# Epoch: [18][680/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009334, lr_decoder: 0.009334, Accuracy: 97.66, Accuracy_Binary: 99.03, Loss: 0.092143
# Epoch: [18][700/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009331, lr_decoder: 0.009331, Accuracy: 97.66, Accuracy_Binary: 99.04, Loss: 0.091742
# Epoch: [18][720/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009329, lr_decoder: 0.009329, Accuracy: 97.65, Accuracy_Binary: 99.02, Loss: 0.092816
# Epoch: [18][740/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009326, lr_decoder: 0.009326, Accuracy: 97.65, Accuracy_Binary: 99.02, Loss: 0.093099
# Epoch: [18][760/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009323, lr_decoder: 0.009323, Accuracy: 97.64, Accuracy_Binary: 99.02, Loss: 0.093180
# Epoch: [18][780/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009321, lr_decoder: 0.009321, Accuracy: 97.65, Accuracy_Binary: 99.03, Loss: 0.092628
# Epoch: [18][800/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009318, lr_decoder: 0.009318, Accuracy: 97.65, Accuracy_Binary: 99.05, Loss: 0.092151
# Epoch: [18][820/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009316, lr_decoder: 0.009316, Accuracy: 97.66, Accuracy_Binary: 99.06, Loss: 0.091693
# Epoch: [18][840/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009313, lr_decoder: 0.009313, Accuracy: 97.66, Accuracy_Binary: 99.07, Loss: 0.091320
# Epoch: [18][860/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009310, lr_decoder: 0.009310, Accuracy: 97.66, Accuracy_Binary: 99.08, Loss: 0.091262
# Epoch: [18][880/5000], Time: 0.72, Data: 0.00, lr_encoder: 0.009308, lr_decoder: 0.009308, Accuracy: 97.66, Accuracy_Binary: 99.09, Loss: 0.090891
# Epoch: [18][900/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009305, lr_decoder: 0.009305, Accuracy: 97.66, Accuracy_Binary: 99.09, Loss: 0.090775
# Epoch: [18][920/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009302, lr_decoder: 0.009302, Accuracy: 97.66, Accuracy_Binary: 99.10, Loss: 0.090389
# Epoch: [18][940/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009300, lr_decoder: 0.009300, Accuracy: 97.67, Accuracy_Binary: 99.10, Loss: 0.090159
# Epoch: [18][960/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009297, lr_decoder: 0.009297, Accuracy: 97.67, Accuracy_Binary: 99.11, Loss: 0.090083
# Epoch: [18][980/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009295, lr_decoder: 0.009295, Accuracy: 97.67, Accuracy_Binary: 99.11, Loss: 0.089781
# Epoch: [18][1000/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009292, lr_decoder: 0.009292, Accuracy: 97.67, Accuracy_Binary: 99.12, Loss: 0.089476
# Epoch: [18][1020/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009289, lr_decoder: 0.009289, Accuracy: 97.68, Accuracy_Binary: 99.13, Loss: 0.089118
# Epoch: [18][1040/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009287, lr_decoder: 0.009287, Accuracy: 97.68, Accuracy_Binary: 99.14, Loss: 0.088856
# Epoch: [18][1060/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009284, lr_decoder: 0.009284, Accuracy: 97.68, Accuracy_Binary: 99.15, Loss: 0.088522
# Epoch: [18][1080/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009282, lr_decoder: 0.009282, Accuracy: 97.68, Accuracy_Binary: 99.15, Loss: 0.088421
# Epoch: [18][1100/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009279, lr_decoder: 0.009279, Accuracy: 97.68, Accuracy_Binary: 99.16, Loss: 0.088213
# Epoch: [18][1120/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009276, lr_decoder: 0.009276, Accuracy: 97.69, Accuracy_Binary: 99.16, Loss: 0.087827
# Epoch: [18][1140/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009274, lr_decoder: 0.009274, Accuracy: 97.69, Accuracy_Binary: 99.17, Loss: 0.087487
# Epoch: [18][1160/5000], Time: 0.73, Data: 0.00, lr_encoder: 0.009271, lr_decoder: 0.009271, Accuracy: 97.69, Accuracy_Binary: 99.18, Loss: 0.087245
